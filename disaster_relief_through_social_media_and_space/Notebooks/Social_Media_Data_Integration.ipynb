# %%
import tweepy

consumer_key = 'your-consumer-key'
consumer_secret = 'your-consumer-secret'
access_import tweepy

class TwitterAPI:
    def __init__(self, consumer_key, consumer_secret, access_token, access_token_secret):
        self.auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
        self.auth.set_access_token(access_token, access_token_secret)
        self.api = tweepy.API(self.auth)

    def search_tweets(self, search_words, date_since, lang="en", num_items=500):
        tweets = tweepy.Cursor(self.api.search, q=search_words, lang=lang, since=date_since).items(num_items)
        return tweets

class TweetPrinter:
    def print_tweets(self, tweets):
        for tweet in tweets:
            print(tweet.text)

# Twitter API credentials
consumer_key = 'your-consumer-key'
consumer_secret = 'your-consumer-secret'
access_token = 'your-access-token'
access_token_secret = 'your-access-token-secret'

# Create instance of TwitterAPI
twitter_api = TwitterAPI(consumer_key, consumer_secret, access_token, access_token_secret)

# Create instance of TweetPrinter
tweet_printer = TweetPrinter()

# Define the search term and the date_since date
search_words = "#Haiyaan OR #YolandaPH"  # Yolanda is the local name for Haiyaan in the Philippines
date_since = "2013-11-01"

# Collect tweets
tweets = twitter_api.search_tweets(search_words, date_since)

# Print tweets
tweet_printer.print_tweets(tweets)token = 'your-access-token'
access_token_secret = 'your-access-token-secret'

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth)

# Define the search term and the date_since date
search_words = "#Haiyaan OR #YolandaPH"  # Yolanda is the local name for Haiyaan in the Philippines
date_since = "2013-11-01"

# Collect tweets
tweets = tweepy.Cursor(api.search,
              q=search_words,
              lang="en",
              since=date_since).items(500)

# Iterate and print tweets
for tweet in tweets:
    print(tweet.text)

# %% [markdown]
# Integrating the above data with the satellite images

# %%
import tweepy
import matplotlib.pyplot as plt
from PIL import Image
import numpy as np

# Twitter API credentials
consumer_key = 'your-consumer-key'
consumer_secret = 'your-consumer-secret'
access_token = 'your-access-token'
access_token_secret = 'your-access-token-secret'

# Authenticate to Twitter API
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)

# Define the search term and the date_since date
search_words = "#Haiyan OR #YolandaPH"
date_since = "2013-11-01"

# Collect tweets
tweets = tweepy.Cursor(api.search, q=search_words, lang="en", since=date_since).items(500)

# Load satellite image 
satellite_image = Image.open('satellite_image.png')

# Convert the image to a numpy array
satellite_image_array = np.array(satellite_image)

# Create a figure with two subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))

# Plot the satellite image
ax1.imshow(satellite_image_array)
ax1.set_title('Satellite Image of Typhoon Haiyan/Yolanda')

# Print tweets in the second subplot
ax2.set_title('Tweets Related to Typhoon Haiyan/Yolanda')
ax2.axis('off')  # Turn off the axis for the tweets subplot
tweet_texts = [tweet.text for tweet in tweets]
for i, tweet_text in enumerate(tweet_texts):
    ax2.text(0.1, 0.9 - i * 0.05, tweet_text, wrap=True)

plt.tight_layout()
plt.show()
